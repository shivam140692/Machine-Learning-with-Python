# %%
#to visualize more than 3 variables

# %%
import pandas as pd
import seaborn as sb

# %%
df=pd.read_csv('loan_data.csv')

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
type(cancer)
# Out:
# sklearn.utils.Bunch

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
    df=pd.DataFrame(data=cancer['data'],columns=cancer['feature_names'])

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
df['target']=cancer['target']

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension   ...    worst texture  worst perimeter  worst area  \
# ...

# %%
df['target'].value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension   ...    worst texture  worst perimeter  worst area  \
# ...

# %%
#Pca itne sare column ko reduce krke ek column bnata hai  in this case 30 columns hai to phle 15 ka woh mean lega 
#and next 15 ka mean leke standard scaling krega in the end hmlog algorithm sirf 2 hi values m hi lgayenge

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=df.drop('target',axis = 1)

# %%
y=df['target']

# %%
ss=StandardScaler()

# %%
scaled_array=ss.fit_transform(x)

# %%
scaled_array
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
X=pd.DataFrame(scaled_array,columns=df.columns[:-1])

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
#PCA always take array as input and PCA always done at last

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)#2 represent kitne columns chaiye mean lene k baad

# %%
x_pca = pca.fit_transform(scaled_array)

# %%
x_pca.shape
# Out:
# (569, 2)

# %%
x_pca
# Out:
# array([[ 9.19283683,  1.94858307],
#        [ 2.3878018 , -3.76817174],
#        [ 5.73389628, -1.0751738 ],
#        ...,
#        [ 1.25617928, -1.90229671],
#        [10.37479406,  1.67201011],
#        [-5.4752433 , -0.67063679]])

# %%
x1=x_pca[:,0]

# %%
x1
# Out:
# array([ 9.19283683,  2.3878018 ,  5.73389628,  7.1229532 ,  3.93530207,
#         2.38024715,  2.23888331,  2.1432985 ,  3.17492429,  6.35174679,
#        -0.81041377,  2.65110048,  8.18503446,  0.34212591,  4.34237919,
#         4.07565618,  0.23005502,  4.41801092,  4.94870355, -1.23706336,
#        -1.57816123, -3.55733637,  4.73321079,  4.20852421,  4.94963207,
#         7.09856285,  3.5102626 ,  3.06405389,  4.00726414,  1.71530973,
#         6.05944551,  2.9022361 ,  4.55478269,  4.99060272,  2.98534079,
#         2.76636916,  1.29619877, -3.7493134 , -0.9980689 ,  0.76526412,
#        -2.15095347, -0.09333139,  9.08799968,  0.99045377, -0.29354655,
#         5.38094041, -4.58193667,  1.70000689, -2.13644528, -1.567479  ,
#        -3.54290556, -3.15781405, -3.45048854,  3.30255095, -0.67461929,
#        -2.85815844,  4.64873887,  2.17686288, -3.72145899, -4.13596294,
#        -2.38583566, -2.57888325,  4.75911215, -2.31413225,  1.69160792,
# ...

# %%
x2=x_pca[:,1]

# %%
x2
# Out:
# array([ 1.94858307e+00, -3.76817174e+00, -1.07517380e+00,  1.02755891e+01,
#        -1.94807157e+00,  3.94992890e+00, -2.69003128e+00,  2.34024401e+00,
#         3.39181295e+00,  7.72717407e+00, -2.65927550e+00,  6.65679266e-02,
#         2.70097649e+00, -9.68279261e-01,  4.86108331e+00,  2.97706118e+00,
#        -1.56475773e+00,  1.41867033e+00, -4.11433352e+00, -1.88214954e-01,
#         5.72808192e-01,  1.66294990e+00,  3.30496373e+00, -5.12836651e+00,
#        -1.54375229e+00,  2.01861034e+00,  2.17162512e+00, -1.87655235e+00,
#         5.37242161e-01, -1.52370502e+00, -7.57177451e-01,  4.00529551e+00,
#         3.37536154e-01, -1.13258891e+00,  7.58423242e-01, -3.54355942e-01,
#         9.13196276e-01, -1.41347312e+00, -3.35129292e+00,  8.86243953e-01,
#        -1.92399162e+00,  2.26075201e+00,  2.01867310e+00,  9.84930020e-01,
#        -1.37099091e-01, -1.34876978e-01,  1.48422032e+00,  2.35227179e+00,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x1,x2,c=df['target'])

# %%
#in above c is like hue in seaborn but question is how to identify?

# %%
x_pca
# Out:
# array([[ 9.19283683,  1.94858307],
#        [ 2.3878018 , -3.76817174],
#        [ 5.73389628, -1.0751738 ],
#        ...,
#        [ 1.25617928, -1.90229671],
#        [10.37479406,  1.67201011],
#        [-5.4752433 , -0.67063679]])

# %%
df['target']==0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19     False
# 20     False
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562     True
# 563     True
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: target, Length: 569, dtype: bool

# %%
x_pca[df['target']==0,0]
# Out:
# array([ 9.19283683,  2.3878018 ,  5.73389628,  7.1229532 ,  3.93530207,
#         2.38024715,  2.23888331,  2.1432985 ,  3.17492429,  6.35174679,
#        -0.81041377,  2.65110048,  8.18503446,  0.34212591,  4.34237919,
#         4.07565618,  0.23005502,  4.41801092,  4.94870355,  4.73321079,
#         4.20852421,  4.94963207,  7.09856285,  3.5102626 ,  3.06405389,
#         4.00726414,  1.71530973,  6.05944551,  2.9022361 ,  4.55478269,
#         4.99060272,  2.98534079,  2.76636916,  1.29619877, -0.9980689 ,
#         0.76526412, -2.15095347, -0.09333139,  9.08799968,  0.99045377,
#        -0.29354655,  5.38094041,  1.70000689,  3.30255095, -0.67461929,
#         4.64873887,  2.17686288,  4.75911215,  1.69160792,  1.81230541,
#         2.70459617,  5.50370532, -0.36170919,  1.42816759,  6.23089651,
#        11.66871465, 10.76924282,  5.03481109,  3.28823538,  0.60760795,
#         3.58356363,  0.25249757,  2.77586557,  4.39622795,  0.61628087,
# ...

# %%
x_pca[df['target']==0,1]
# Out:
# array([ 1.94858307, -3.76817174, -1.0751738 , 10.27558912, -1.94807157,
#         3.9499289 , -2.69003128,  2.34024401,  3.39181295,  7.72717407,
#        -2.6592755 ,  0.06656793,  2.70097649, -0.96827926,  4.86108331,
#         2.97706118, -1.56475773,  1.41867033, -4.11433352,  3.30496373,
#        -5.12836651, -1.54375229,  2.01861034,  2.17162512, -1.87655235,
#         0.53724216, -1.52370502, -0.75717745,  4.00529551,  0.33753615,
#        -1.13258891,  0.75842324, -0.35435594,  0.91319628, -3.35129292,
#         0.88624395, -1.92399162,  2.26075201,  2.0186731 ,  0.98493002,
#        -0.13709909, -0.13487698,  2.35227179, -1.1309378 , -2.11640972,
#        -2.31033257,  0.97211605,  3.01168051,  1.54067656,  0.72274019,
#        -4.43714177,  0.93832542,  0.11973909, -1.96710141,  0.92006954,
#         4.7486172 , -2.2579829 ,  0.77440916, -1.66823706,  0.16221452,
#        -2.20666184, -0.53135155,  0.55800053, -2.12350771,  0.63891167,
# ...

# %%
plt.scatter(x_pca[df['target']==0,0],x_pca[df['target']==0,1],color = 'red')
plt.scatter(x_pca[df['target']==1,0],x_pca[df['target']==1,1],color = 'yellow')
